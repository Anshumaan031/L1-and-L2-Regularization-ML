# %% [markdown]
# # Feature Selection & Regularization
#
# In this notebook, we will see:
# - Forward and backward subset selection
# - L1 and L2 regularization (LASSO, ridge and elastic net)
#
# We will apply these methods to the example from Notebook 3, using the same dataset (diabetes.csv).

# %%
import pandas as pd

# Load data
df = pd.read_csv('diabetes.csv', index_col = 0)
df
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6  target
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0   151.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0    75.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0   141.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0   206.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0   135.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...     ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0   178.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0   104.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0   132.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0   220.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0    57.0
#
# [442 rows x 11 columns]

# %% [markdown]
# We'll use the same X, and generate polynomial features up to degree 2. For simplicitly, let's do these all at once.
#
# Recall from Notebook 3 that including all of these polynomial features resulted in *worse* performance!
#
# Let's see if subset selection and regularization can identify the important features to keep.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 2)

X = pd.DataFrame(data = poly.fit_transform(df[['bmi', 'bp', 's3', 's4', 's5']]),
                 columns = poly.get_feature_names_out()
                )
y = df['target']

X
# Out:
#        1   bmi      bp    s3    s4      s5    bmi^2    bmi bp  bmi s3  \
# 0    1.0  32.1  101.00  38.0  4.00  4.8598  1030.41  3242.100  1219.8
# 1    1.0  21.6   87.00  70.0  3.00  3.8918   466.56  1879.200  1512.0
# 2    1.0  30.5   93.00  41.0  4.00  4.6728   930.25  2836.500  1250.5
# 3    1.0  25.3   84.00  40.0  5.00  4.8903   640.09  2125.200  1012.0
# 4    1.0  23.0  101.00  52.0  4.00  4.2905   529.00  2323.000  1196.0
# ..   ...   ...     ...   ...   ...     ...      ...       ...     ...
# 437  1.0  28.2  112.00  42.0  4.00  4.9836   795.24  3158.400  1184.4
# 438  1.0  24.9   75.00  42.0  5.00  4.4427   620.01  1867.500  1045.8
# 439  1.0  24.9   99.67  43.0  3.77  4.1271   620.01  2481.783  1070.7
# 440  1.0  30.0   95.00  42.0  4.79  5.1299   900.00  2850.000  1260.0
# 441  1.0  19.6   71.00  97.0  3.00  4.5951   384.16  1391.600  1901.2
#
#       bmi s4  ...        bp^2    bp s3     bp s4       bp s5    s3^2   s3 s4  \
# 0    128.400  ...  10201.0000  3838.00  404.0000  490.839800  1444.0  152.00
# 1     64.800  ...   7569.0000  6090.00  261.0000  338.586600  4900.0  210.00
# 2    122.000  ...   8649.0000  3813.00  372.0000  434.570400  1681.0  164.00
# 3    126.500  ...   7056.0000  3360.00  420.0000  410.785200  1600.0  200.00
# 4     92.000  ...  10201.0000  5252.00  404.0000  433.340500  2704.0  208.00
# ..       ...  ...         ...      ...       ...         ...     ...     ...
# 437  112.800  ...  12544.0000  4704.00  448.0000  558.163200  1764.0  168.00
# 438  124.500  ...   5625.0000  3150.00  375.0000  333.202500  1764.0  210.00
# 439   93.873  ...   9934.1089  4285.81  375.7559  411.348057  1849.0  162.11
# 440  143.700  ...   9025.0000  3990.00  455.0500  487.340500  1764.0  201.18
# 441   58.800  ...   5041.0000  6887.00  213.0000  326.252100  9409.0  291.00
#
#         s3 s5     s4^2      s4 s5       s5^2
# 0    184.6724  16.0000  19.439200  23.617656
# 1    272.4260   9.0000  11.675400  15.146107
# 2    191.5848  16.0000  18.691200  21.835060
# 3    195.6120  25.0000  24.451500  23.915034
# 4    223.1060  16.0000  17.162000  18.408390
# ..        ...      ...        ...        ...
# 437  209.3112  16.0000  19.934400  24.836269
# 438  186.5934  25.0000  22.213500  19.737583
# 439  177.4653  14.2129  15.559167  17.032954
# 440  215.4558  22.9441  24.572221  26.315874
# 441  445.7247   9.0000  13.785300  21.114944
#
# [442 rows x 21 columns]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

lin = make_pipeline(
    StandardScaler(), 
    LinearRegression()
)

lin
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# Let's apply 5-fold cross validation liked we learned in Notebook 4:

# %%
from sklearn.model_selection import KFold, cross_validate

# Initialize cross validator
cv = KFold(n_splits = 5, shuffle = True, random_state = 23)

# Cross validate (cross_val_score computes NEGATIVE mean squared error)
results = cross_validate(lin, X, y, scoring = 'neg_mean_squared_error', cv = cv)
results = pd.DataFrame(results)
results
# Out:
#    fit_time  score_time   test_score
# 0  0.016677    0.000000 -3808.032833
# 1  0.008072    0.000000 -2469.683469
# 2  0.000000    0.000000 -3754.698790
# 3  0.008172    0.000000 -3269.591912
# 4  0.000000    0.008295 -3111.008339

# %%
# Extract the MSE (note the minus sign)
mse = - results['test_score']
mse
# Out:
# 0    3808.032833
# 1    2469.683469
# 2    3754.698790
# 3    3269.591912
# 4    3111.008339
# Name: test_score, dtype: float64

# %%
mse.mean()
# Out:
# 3282.603068693358

# %% [markdown]
# # Displaying coefficients
#
# Using ```cross_validate``` made it much easier to compute the test errors. However, if we want to look at the coefficients for the models trained on each fold, we can't: the models were not stored anywhere!
#
# In order to extract the linear regression coefficients from each of the 5 trained models, we need to set ```return_estimator = True``` in ```cross_validate```:

# %%
results = cross_validate(lin, X, y, scoring = 'neg_mean_squared_error', cv = cv, return_estimator = True)  #return estimator is true if we want the corss validation to keep the model
results
# Out:
# {'fit_time': array([0.00803399, 0.01595449, 0.00799799, 0.        , 0.00819373]),
#  'score_time': array([0., 0., 0., 0., 0.]),
#  'estimator': [Pipeline(steps=[('standardscaler', StandardScaler()),
#                   ('linearregression', LinearRegression())]),
#   Pipeline(steps=[('standardscaler', StandardScaler()),
#                   ('linearregression', LinearRegression())]),
#   Pipeline(steps=[('standardscaler', StandardScaler()),
#                   ('linearregression', LinearRegression())]),
#   Pipeline(steps=[('standardscaler', StandardScaler()),
#                   ('linearregression', LinearRegression())]),
#   Pipeline(steps=[('standardscaler', StandardScaler()),
#                   ('linearregression', LinearRegression())])],
#  'test_score': array([-3808.03283314, -2469.68346928, -3754.69878987, -3269.591912  ,
#         -3111.00833918])}

# %% [markdown]
# Notice that there are 5 estimators, corresponding to the 5 folds.
#
# Let's extract the coefficients from each of the 5 estimators, and place them in a DataFrame:

# %%
# Initialize an empty dataframe
coefs = pd.DataFrame(index = X.columns)  #creaitng a dataframe to store the coefficients

# Insert 1 column of coefficients for each fold
for i in range(5):
    # Select the model
    model = results['estimator'][i]  #gives the list of models
    
    # Extract the coefficients
    model_coefs = model.named_steps['linearregression'].coef_
    
    # Insert these as a new column in our dataframe
    coefs[i] = model_coefs

coefs
# Out:
#                  0          1          2           3           4
# 1         0.000000   0.000000   0.000000    0.000000    0.000000
# bmi     -81.866939 -45.076573 -67.205994  -21.187111   -1.053212
# bp      -74.376245 -32.086037 -79.271806  -92.140973 -101.693220
# s3        2.513771  48.634838 -51.045139  -73.615974   22.095463
# s4       20.879524  75.890406  38.549719  -29.183725   42.933032
# s5       80.800912  54.670463 -33.034527    5.731403   17.260630
# bmi^2    52.214201  40.945307  42.509058  -17.443256   11.704104
# bmi bp   85.624303  20.436174  72.672053  116.903540   63.611928
# bmi s3  -19.512785  -6.189257  -3.453199    8.391538  -43.479465
# bmi s4  -14.941477 -11.122714  -9.073300   66.830668  -40.740385
# bmi s5   27.740549  40.356265  17.149019  -61.078318   28.433016
# bp^2      5.091859   3.925243 -15.210667   -0.183537   10.165315
# bp s3    23.963509  23.262348  28.083326    8.240035   30.618070
# bp s4   -10.403503   8.728956   1.536793  -43.149132    7.430889
# bp s5    35.342578  17.952605  76.340526   81.963246   75.350486
# s3^2      0.718178 -34.030268 -17.729808    4.199019  -37.415805
# s3 s4     7.903919 -21.940264 -24.741495  -10.562764  -27.380714
# s3 s5   -27.230551 -15.437650  59.762362   47.944258   46.711523
# s4^2     77.668608 -16.288610 -31.260887  -23.147885  -17.271747
# s4 s5  -118.013561 -40.000685  40.369406   60.360593   44.318608
# s5^2    -40.401651 -37.590048 -26.989605  -34.379937  -78.584666

# %% [markdown]
# We can add some colour to make the high and low coefficients more obvious:

# %%
coefs.style.background_gradient(cmap = 'bwr_r', vmin = -100, vmax = 100)
# Out:
# <style type="text/css">
# #T_2e276_row0_col0, #T_2e276_row0_col1, #T_2e276_row0_col2, #T_2e276_row0_col3, #T_2e276_row0_col4, #T_2e276_row15_col0 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_2e276_row1_col0 {
#   background-color: #ff2e2e;
#   color: #f1f1f1;
# }
# #T_2e276_row1_col1 {
#   background-color: #ff8c8c;
#   color: #000000;
# }
# #T_2e276_row1_col2 {
#   background-color: #ff5252;
#   color: #f1f1f1;
# }
# #T_2e276_row1_col3 {
#   background-color: #ffc8c8;
#   color: #000000;
# }
# #T_2e276_row1_col4 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_2e276_row2_col0 {
#   background-color: #ff4040;
#   color: #f1f1f1;
# }
# #T_2e276_row2_col1 {
#   background-color: #ffacac;
#   color: #000000;
# }
# #T_2e276_row2_col2 {
#   background-color: #ff3434;
#   color: #f1f1f1;
# }
# #T_2e276_row2_col3 {
#   background-color: #ff1414;
#   color: #f1f1f1;
# }
# #T_2e276_row2_col4, #T_2e276_row19_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_2e276_row3_col0 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_2e276_row3_col1 {
#   background-color: #8282ff;
#   color: #f1f1f1;
# }
# #T_2e276_row3_col2 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_2e276_row3_col3 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_2e276_row3_col4 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_2e276_row4_col0, #T_2e276_row7_col1 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_2e276_row4_col1, #T_2e276_row14_col2 {
#   background-color: #3c3cff;
#   color: #f1f1f1;
# }
# #T_2e276_row4_col2 {
#   background-color: #9c9cff;
#   color: #f1f1f1;
# }
# #T_2e276_row4_col3 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_2e276_row4_col4, #T_2e276_row6_col2 {
#   background-color: #9292ff;
#   color: #f1f1f1;
# }
# #T_2e276_row5_col0 {
#   background-color: #3030ff;
#   color: #f1f1f1;
# }
# #T_2e276_row5_col1 {
#   background-color: #7474ff;
#   color: #f1f1f1;
# }
# #T_2e276_row5_col2 {
#   background-color: #ffaaaa;
#   color: #000000;
# }
# #T_2e276_row5_col3 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_2e276_row5_col4, #T_2e276_row14_col1 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_2e276_row6_col0 {
#   background-color: #7a7aff;
#   color: #f1f1f1;
# }
# #T_2e276_row6_col1 {
#   background-color: #9696ff;
#   color: #f1f1f1;
# }
# #T_2e276_row6_col3, #T_2e276_row15_col2, #T_2e276_row18_col4 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_2e276_row6_col4 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_2e276_row7_col0 {
#   background-color: #2424ff;
#   color: #f1f1f1;
# }
# #T_2e276_row7_col2 {
#   background-color: #4444ff;
#   color: #f1f1f1;
# }
# #T_2e276_row7_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_2e276_row7_col4 {
#   background-color: #5c5cff;
#   color: #f1f1f1;
# }
# #T_2e276_row8_col0 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_2e276_row8_col1 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_2e276_row8_col2 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_2e276_row8_col3, #T_2e276_row12_col3, #T_2e276_row16_col0 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_2e276_row8_col4, #T_2e276_row13_col3 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_2e276_row9_col0, #T_2e276_row11_col2, #T_2e276_row17_col1 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_2e276_row9_col1 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# #T_2e276_row9_col2 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_2e276_row9_col3 {
#   background-color: #5454ff;
#   color: #f1f1f1;
# }
# #T_2e276_row9_col4 {
#   background-color: #ff9696;
#   color: #000000;
# }
# #T_2e276_row10_col0, #T_2e276_row12_col2 {
#   background-color: #b8b8ff;
#   color: #000000;
# }
# #T_2e276_row10_col1, #T_2e276_row19_col2 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_2e276_row10_col2 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_2e276_row10_col3 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_2e276_row10_col4 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_2e276_row11_col0 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_2e276_row11_col1, #T_2e276_row15_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_2e276_row11_col3 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_2e276_row11_col4 {
#   background-color: #e4e4ff;
#   color: #000000;
# }
# #T_2e276_row12_col0 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# #T_2e276_row12_col1 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_2e276_row12_col4 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_2e276_row13_col0, #T_2e276_row16_col3 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_2e276_row13_col1 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_2e276_row13_col2 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_2e276_row13_col4 {
#   background-color: #ececff;
#   color: #000000;
# }
# #T_2e276_row14_col0 {
#   background-color: #a4a4ff;
#   color: #000000;
# }
# #T_2e276_row14_col3 {
#   background-color: #2e2eff;
#   color: #f1f1f1;
# }
# #T_2e276_row14_col4 {
#   background-color: #3e3eff;
#   color: #f1f1f1;
# }
# #T_2e276_row15_col1 {
#   background-color: #ffa8a8;
#   color: #000000;
# }
# #T_2e276_row15_col4 {
#   background-color: #ffa0a0;
#   color: #000000;
# }
# #T_2e276_row16_col1 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_2e276_row16_col2 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_2e276_row16_col4 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_2e276_row17_col0, #T_2e276_row20_col2 {
#   background-color: #ffbaba;
#   color: #000000;
# }
# #T_2e276_row17_col2 {
#   background-color: #6666ff;
#   color: #f1f1f1;
# }
# #T_2e276_row17_col3 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_2e276_row17_col4 {
#   background-color: #8888ff;
#   color: #f1f1f1;
# }
# #T_2e276_row18_col0 {
#   background-color: #3838ff;
#   color: #f1f1f1;
# }
# #T_2e276_row18_col1 {
#   background-color: #ffd6d6;
#   color: #000000;
# }
# #T_2e276_row18_col2 {
#   background-color: #ffaeae;
#   color: #000000;
# }
# #T_2e276_row18_col3 {
#   background-color: #ffc4c4;
#   color: #000000;
# }
# #T_2e276_row19_col1, #T_2e276_row20_col0 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_2e276_row19_col3 {
#   background-color: #6464ff;
#   color: #f1f1f1;
# }
# #T_2e276_row19_col4 {
#   background-color: #8e8eff;
#   color: #f1f1f1;
# }
# #T_2e276_row20_col1 {
#   background-color: #ff9e9e;
#   color: #000000;
# }
# #T_2e276_row20_col3 {
#   background-color: #ffa6a6;
#   color: #000000;
# }
# #T_2e276_row20_col4 {
#   background-color: #ff3636;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e276">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e276_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2e276_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2e276_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2e276_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2e276_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e276_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2e276_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_2e276_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_2e276_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2e276_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_2e276_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e276_level0_row1" class="row_heading level0 row1" >bmi</th>
#       <td id="T_2e276_row1_col0" class="data row1 col0" >-81.866939</td>
#       <td id="T_2e276_row1_col1" class="data row1 col1" >-45.076573</td>
#       <td id="T_2e276_row1_col2" class="data row1 col2" >-67.205994</td>
#       <td id="T_2e276_row1_col3" class="data row1 col3" >-21.187111</td>
#       <td id="T_2e276_row1_col4" class="data row1 col4" >-1.053212</td>
#     </tr>
#     <tr>
#       <th id="T_2e276_level0_row2" class="row_heading level0 row2" >bp</th>
#       <td id="T_2e276_row2_col0" class="data row2 col0" >-74.376245</td>
#       <td id="T_2e276_row2_col1" class="data row2 col1" >-32.086037</td>
#       <td id="T_2e276_row2_col2" class="data row2 col2" >-79.271806</td>
#       <td

# %% [markdown]
# Note that some features have consistently positive or negative coefficients across all folds, but other feature's coefficients fluctuate wildly, indicating that we are probably overfitting.
#
# This is an indication that feature selection or regularization might be needed.

# %% [markdown]
# ## Feature selection
#
# The above model was trained on all features. Let's see if forward and backward selection pick out more meaningful features.
#
# Feature selection can be very easily done using sklearn's [SequentialFeatureSelector](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html).
#
# This is a transformation step, so we can add it to our pipeline.

# %%
from sklearn.feature_selection import SequentialFeatureSelector

forward = SequentialFeatureSelector(lin, # <- specify the model to use 
                                    direction = 'forward', # <- set the direction
                                    n_features_to_select = 'auto',
                                    scoring = 'neg_mean_squared_error', 
                                    tol = 10, # Add feature if it improves MSE by at least this amount  #this value is adjusted according to mean squared error
                                    cv = cv
                                   )

forward.fit(X, y)
forward.get_feature_names_out()
# Out:
# array(['s3', 'bmi s5', 'bp s5', 's3 s4'], dtype=object)

# %%
backward = SequentialFeatureSelector(lin, 
                                     direction = 'backward', # <- different direction
                                     n_features_to_select = 'auto',
                                     scoring = 'neg_mean_squared_error',
                                     tol = 10, # Remove feature if it improves MSE by at least this amount
                                     cv = cv)
backward.fit(X, y)
backward.get_feature_names_out()
# Out:
# array(['1', 'bp', 's3', 's4', 'bmi bp', 'bmi s3', 'bmi s4', 'bp^2',
#        'bp s3', 'bp s4', 'bp s5', 's3^2', 's3 s4', 's3 s5', 's5^2'],
#       dtype=object)

# %% [markdown]
# Let's compare the MSE using these features, versus the full model above with all features.

# %%
X_forward  = X[forward.get_feature_names_out()]
X_backward = X[backward.get_feature_names_out()]

forward_mse = - cross_validate(lin, X_forward, y, scoring = 'neg_mean_squared_error', cv = cv)['test_score'].mean()
backward_mse = - cross_validate(lin, X_backward, y, scoring = 'neg_mean_squared_error', cv = cv)['test_score'].mean()

print('Full model:\t', mse.mean())
print('Forward:\t', forward_mse)
print('Backward:\t', backward_mse)
# Out:
# Full model:	 3282.603068693358
# Forward:	 3022.6080465738683
# Backward:	 3024.365924049757

# %% [markdown]
# Both forward and backward selection:
# - have picked out a subset of all features
# - have improved MSE by quite a bit
#
# Both forward and backward selection have similar MSE, but forward selection achieved this with much fewer features!
#
# Try with different values of ```tol```, or set ```n_features_to_select``` to a fixed number instead.
#
#
# ## LASSO regression
#
# Let's now see what happens when we use regularization instead of feature selection.
#
# Let's start with [LASSO](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html), with ```alpha = 1``` (recall that ```alpha``` is the same as $\lambda$)
#
# The following code is mostly a repeat of what we've seen, but with LASSO instead of Linear Regression.

# %%
from sklearn.linear_model import Lasso

# Initialize model (LASSO)
lasso = make_pipeline(StandardScaler(), Lasso(alpha = 1))

# %%
# Cross validate
results = cross_validate(lasso, # <- lasso instead of lin
                         X, y, scoring = 'neg_mean_squared_error', cv = cv, return_estimator = True)

mse = - results['test_score']
mse.mean()
# Out:
# 3029.4666319113794

# %% [markdown]
# We have also managed to improve the performance! Let's look at the coefficients:

# %%
# Display coefficients in a nice DataFrame
coefs = pd.DataFrame(index = X.columns)

for i in range(5):
    model = results['estimator'][i]
    coefs[i] = model.named_steps['lasso'].coef_ # remember to specify the correct step in the pipeline

coefs
# Out:
#                 0          1          2          3          4
# 1        0.000000   0.000000   0.000000   0.000000   0.000000
# bmi      0.000000   0.000000   0.000000   0.000000   0.000000
# bp       0.000000   0.000000   0.000000   0.000000   0.000000
# s3      -0.000000  -4.439389  -6.706802  -7.623467  -4.289952
# s4       0.000000   0.000000   0.000000   0.000000   0.000000
# s5      23.770583  10.449538  21.204453  18.032042  16.019595
# bmi^2   13.447530   7.951429   8.104222   0.000000   0.000000
# bmi bp  22.084885  10.027020  21.600845  29.417419  24.362847
# bmi s3  -6.316139  -0.000000  -0.000000  -0.000000  -3.771338
# bmi s4   2.370266   0.000000   0.000000   0.033388   0.000000
# bmi s5   2.330237  20.747560   8.473513   8.760257  17.871233
# bp^2     0.000000   0.000000   0.000000   0.000000   0.000000
# bp s3   -0.000000  -0.000000  -0.000000  -0.000000  -0.000000
# bp s4    0.000000   0.000000   0.000000   0.000000   0.000000
# bp s5    0.000000   8.131265   0.000000   0.000000   0.175217
# s3^2    -0.000000  -3.586836  -0.000000  -0.000000  -0.000000
# s3 s4   -4.360892  -3.655541  -3.983023  -2.501566  -4.385367
# s3 s5   -0.000000  -0.000000  -0.000000  -0.000000  -0.000000
# s4^2     0.000000  -0.000000   0.000000   0.000000   0.000000
# s4 s5    0.000000   0.000000   0.000000   0.000000   0.000000
# s5^2     0.000000   0.000000   0.781618   0.000000   0.000000

# %% [markdown]
# We see that many of the coefficients are now zero! Let's remove the non-zero entries and colour them:

# %%
coefs[(coefs != 0).sum(axis = 1) > 0].style.background_gradient(cmap = 'bwr_r', vmin = -100, vmax = 100)
# Out:
# <style type="text/css">
# #T_86b78_row0_col0, #T_86b78_row2_col3, #T_86b78_row2_col4, #T_86b78_row4_col1, #T_86b78_row4_col2, #T_86b78_row4_col3, #T_86b78_row5_col1, #T_86b78_row5_col2, #T_86b78_row5_col3, #T_86b78_row5_col4, #T_86b78_row7_col0, #T_86b78_row7_col2, #T_86b78_row7_col3, #T_86b78_row7_col4, #T_86b78_row8_col0, #T_86b78_row8_col2, #T_86b78_row8_col3, #T_86b78_row8_col4, #T_86b78_row10_col0, #T_86b78_row10_col1, #T_86b78_row10_col3, #T_86b78_row10_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_86b78_row0_col1, #T_86b78_row0_col4, #T_86b78_row9_col0, #T_86b78_row9_col2, #T_86b78_row9_col4 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_86b78_row0_col2, #T_86b78_row4_col0 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_86b78_row0_col3 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_86b78_row1_col0 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# #T_86b78_row1_col1 {
#   background-color: #e4e4ff;
#   color: #000000;
# }
# #T_86b78_row1_col2, #T_86b78_row3_col2 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_86b78_row1_col3 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_86b78_row1_col4 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_86b78_row2_col0 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_86b78_row2_col1, #T_86b78_row2_col2, #T_86b78_row6_col2, #T_86b78_row7_col1 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_86b78_row3_col0 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_86b78_row3_col1 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_86b78_row3_col3 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_86b78_row3_col4 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_86b78_row4_col4, #T_86b78_row8_col1, #T_86b78_row9_col1 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_86b78_row5_col0 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_86b78_row6_col0 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_86b78_row6_col1 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_86b78_row6_col3 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_86b78_row6_col4 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_86b78_row9_col3 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_86b78_row10_col2 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# </style>
# <table id="T_86b78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86b78_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_86b78_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_86b78_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_86b78_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_86b78_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86b78_level0_row0" class="row_heading level0 row0" >s3</th>
#       <td id="T_86b78_row0_col0" class="data row0 col0" >-0.000000</td>
#       <td id="T_86b78_row0_col1" class="data row0 col1" >-4.439389</td>
#       <td id="T_86b78_row0_col2" class="data row0 col2" >-6.706802</td>
#       <td id="T_86b78_row0_col3" class="data row0 col3" >-7.623467</td>
#       <td id="T_86b78_row0_col4" class="data row0 col4" >-4.289952</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_86b78_row1_col0" class="data row1 col0" >23.770583</td>
#       <td id="T_86b78_row1_col1" class="data row1 col1" >10.449538</td>
#       <td id="T_86b78_row1_col2" class="data row1 col2" >21.204453</td>
#       <td id="T_86b78_row1_col3" class="data row1 col3" >18.032042</td>
#       <td id="T_86b78_row1_col4" class="data row1 col4" >16.019595</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row2" class="row_heading level0 row2" >bmi^2</th>
#       <td id="T_86b78_row2_col0" class="data row2 col0" >13.447530</td>
#       <td id="T_86b78_row2_col1" class="data row2 col1" >7.951429</td>
#       <td id="T_86b78_row2_col2" class="data row2 col2" >8.104222</td>
#       <td id="T_86b78_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_86b78_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row3" class="row_heading level0 row3" >bmi bp</th>
#       <td id="T_86b78_row3_col0" class="data row3 col0" >22.084885</td>
#       <td id="T_86b78_row3_col1" class="data row3 col1" >10.027020</td>
#       <td id="T_86b78_row3_col2" class="data row3 col2" >21.600845</td>
#       <td id="T_86b78_row3_col3" class="data row3 col3" >29.417419</td>
#       <td id="T_86b78_row3_col4" class="data row3 col4" >24.362847</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row4" class="row_heading level0 row4" >bmi s3</th>
#       <td id="T_86b78_row4_col0" class="data row4 col0" >-6.316139</td>
#       <td id="T_86b78_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_86b78_row4_col2" class="data row4 col2" >-0.000000</td>
#       <td id="T_86b78_row4_col3" class="data row4 col3" >-0.000000</td>
#       <td id="T_86b78_row4_col4" class="data row4 col4" >-3.771338</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row5" class="row_heading level0 row5" >bmi s4</th>
#       <td id="T_86b78_row5_col0" class="data row5 col0" >2.370266</td>
#       <td id="T_86b78_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_86b78_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_86b78_row5_col3" class="data row5 col3" >0.033388</td>
#       <td id="T_86b78_row5_col4" class="data row5 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row6" class="row_heading level0 row6" >bmi s5</th>
#       <td id="T_86b78_row6_col0" class="data row6 col0" >2.330237</td>
#       <td id="T_86b78_row6_col1" class="data row6 col1" >20.747560</td>
#       <td id="T_86b78_row6_col2" class="data row6 col2" >8.473513</td>
#       <td id="T_86b78_row6_col3" class="data row6 col3" >8.760257</td>
#       <td id="T_86b78_row6_col4" class="data row6 col4" >17.871233</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row7" class="row_heading level0 row7" >bp s5</th>
#       <td id="T_86b78_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_86b78_row7_col1" class="data row7 col1" >8.131265</td>
#       <td id="T_86b78_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_86b78_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_86b78_row7_col4" class="data row7 col4" >0.175217</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row8" class="row_heading level0 row8" >s3^2</th>
#       <td id="T_86b78_row8_col0" class="data row8 col0" >-0.000000</td>
#       <td id="T_86b78_row8_col1" class="data row8 col1" >-3.586836</td>
#       <td id="T_86b78_row8_col2" class="data row8 col2" >-0.000000</td>
#       <td id="T_86b78_row8_col3" class="data row8 col3" >-0.000000</td>
#       <td id="T_86b78_row8_col4" class="data row8 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row9" class="row_heading level0 row9" >s3 s4</th>
#       <td id="T_86b78_row9_col0" class="data row9 col0" >-4.360892</td>
#       <td id="T_86b78_row9_col1" class="data row9 col1" >-3.655541</td>
#       <td id="T_86b78_row9_col2" class="data row9 col2" >-3.983023</td>
#       <td id="T_86b78_row9_col3" class="data row9 col3" >-2.501566</td>
#       <td id="T_86b78_row9_col4" class="data row9 col4" >-4.385367</td>
#     </tr>
#     <tr>
#       <th id="T_86b78_level0_row10" class="row_heading level0 row10" >s5^2</th>
#       <td id="T_86b78_row10_col0" class="data row10 col0" >0.000000</td>
#       <td id="T_86b78_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_86b78_row10_col2" class="data row10 col2" >0.781618</td>
#       <td id="T_86b78_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_86b78_row10_col4" class="data row10 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare these to the coefficients we saw in forward and backward selection.
#
# In summary, by doing LASSO:
# - Coefficients are generally smaller, and fluctuate less between folds
# - Many coefficients are 0
# - MSE has improved
#
# Note that this was done with a single ```alpha = 1```. In practice, we usually try a few alphas ranging from 0.0001, 0.001, ... 1, 10, 1000, and then pick the best one.

# %% [markdown]
# ## Ridge regression
#
# Let's try this with [Ridge regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge)

# %%
from sklearn.linear_model import Ridge

# Initialize model (Ridge)
ridge = make_pipeline(StandardScaler(), Ridge(alpha = 1))

# %%
# Cross validate
results = cross_validate(ridge, X, y, scoring = 'neg_mean_squared_error', cv = cv, return_estimator = True)

mse = - results['test_score']
mse.mean()
# Out:
# 3088.2594739569568

# %%
# Display coefficients in a nice DataFrame
coefs = pd.DataFrame(index = X.columns)

for i in range(5):
    model = results['estimator'][i]
    coefs[i] = model.named_steps['ridge'].coef_ # remember to specify the correct step

coefs[(coefs != 0).sum(axis = 1) > 0].style.background_gradient(cmap = 'bwr_r', vmin = -100, vmax = 100)
# Out:
# <style type="text/css">
# #T_f145e_row0_col0, #T_f145e_row18_col0 {
#   background-color: #ffa8a8;
#   color: #000000;
# }
# #T_f145e_row0_col1 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_f145e_row0_col2 {
#   background-color: #ffb0b0;
#   color: #000000;
# }
# #T_f145e_row0_col3, #T_f145e_row9_col3, #T_f145e_row17_col2 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_f145e_row0_col4, #T_f145e_row14_col2 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_f145e_row1_col0 {
#   background-color: #ffa2a2;
#   color: #000000;
# }
# #T_f145e_row1_col1 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_f145e_row1_col2 {
#   background-color: #ff9696;
#   color: #000000;
# }
# #T_f145e_row1_col3 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_f145e_row1_col4 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_f145e_row2_col0, #T_f145e_row10_col2, #T_f145e_row19_col2 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_f145e_row2_col1, #T_f145e_row3_col3, #T_f145e_row11_col3, #T_f145e_row16_col1 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_f145e_row2_col2, #T_f145e_row19_col4 {
#   background-color: #ffcaca;
#   color: #000000;
# }
# #T_f145e_row2_col3, #T_f145e_row7_col4 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_f145e_row2_col4, #T_f145e_row19_col3 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_f145e_row3_col0, #T_f145e_row18_col2 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_f145e_row3_col1 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_f145e_row3_col2, #T_f145e_row16_col0 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_f145e_row3_col4, #T_f145e_row4_col4, #T_f145e_row11_col1 {
#   background-color: #dadaff;
#   color: #000000;
# }
# #T_f145e_row4_col0, #T_f145e_row5_col0, #T_f145e_row17_col0 {
#   background-color: #aeaeff;
#   color: #000000;
# }
# #T_f145e_row4_col1, #T_f145e_row13_col4, #T_f145e_row16_col3 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_f145e_row4_col2, #T_f145e_row5_col3 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_f145e_row4_col3, #T_f145e_row9_col2 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_f145e_row5_col1, #T_f145e_row13_col2 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_f145e_row5_col2, #T_f145e_row8_col3, #T_f145e_row16_col2 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_f145e_row5_col4 {
#   background-color: #d8d8ff;
#   color: #000000;
# }
# #T_f145e_row6_col0 {
#   background-color: #7272ff;
#   color: #f1f1f1;
# }
# #T_f145e_row6_col1 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_f145e_row6_col2 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_f145e_row6_col3 {
#   background-color: #5c5cff;
#   color: #f1f1f1;
# }
# #T_f145e_row6_col4 {
#   background-color: #9292ff;
#   color: #f1f1f1;
# }
# #T_f145e_row7_col0 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_f145e_row7_col1, #T_f145e_row14_col0, #T_f145e_row15_col3 {
#   background-color: #ffe6e6;
#   color: #000000;
# }
# #T_f145e_row7_col2, #T_f145e_row17_col1 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_f145e_row7_col3 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_f145e_row8_col0, #T_f145e_row17_col4 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_f145e_row8_col1, #T_f145e_row18_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_f145e_row8_col2 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_f145e_row8_col4 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_f145e_row9_col0 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_f145e_row9_col1 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_f145e_row9_col4, #T_f145e_row11_col2 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_f145e_row10_col0, #T_f145e_row10_col3 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_f145e_row10_col1 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_f145e_row10_col4 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_f145e_row11_col0 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_f145e_row11_col4 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_f145e_row12_col0, #T_f145e_row14_col3 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_f145e_row12_col1, #T_f145e_row12_col2, #T_f145e_row18_col3 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_f145e_row12_col3, #T_f145e_row14_col4, #T_f145e_row19_col1 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_f145e_row12_col4 {
#   background-color: #ececff;
#   color: #000000;
# }
# #T_f145e_row13_col0, #T_f145e_row13_col1 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_f145e_row13_col3 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_f145e_row14_col1, #T_f145e_row18_col1 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# #T_f145e_row15_col0 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_f145e_row15_col1, #T_f145e_row17_col3 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_f145e_row15_col2 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_f145e_row15_col4 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_f145e_row16_col4 {
#   background-color: #bebeff;
#   color: #000000;
# }
# #T_f145e_row19_col0 {
#   background-color: #ffd6d6;
#   color: #000000;
# }
# </style>
# <table id="T_f145e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f145e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f145e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f145e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f145e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f145e_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f145e_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_f145e_row0_col0" class="data row0 col0" >-33.815122</td>
#       <td id="T_f145e_row0_col1" class="data row0 col1" >-17.912446</td>
#       <td id="T_f145e_row0_col2" class="data row0 col2" >-31.001823</td>
#       <td id="T_f145e_row0_col3" class="data row0 col3" >-12.154190</td>
#       <td id="T_f145e_row0_col4" class="data row0 col4" >-10.858104</td>
#     </tr>
#     <tr>
#       <th id="T_f145e_level0_row1" class="row_heading level0 row1" >bp</th>
#       <td id="T_f145e_row1_col0" class="data row1 col0" >-36.088006</td>
#       <td id="T_f145e_row1_col1" class="data row1 col1" >-16.816606</td>
#       <td id="T_f145e_row1_col2" class="data row1 col2" >-40.854075</td>
#       <td id="T_f145e_row1_col3" class="data row1 col3" >-40.152649</td>
#       <td id="T_f145e_row1_col4" class="data row1 col4" >-43.420708</td>
#     </tr>
#     <tr>
#       <th id="T_f145e_level0_row2" class="row_heading level0 row2" >s3</th>
#       <td id="T_f145e_row2_col0" class="data row2 col0" >-2.146586</td>
#       <td id="T_f145e_row2_col1" class="data row2 col1" >1.651688</td>
#       <td id="T_f145e_row2_col2" class="data row2 col2" >-20.585915</td>
#       <td id="T_f145e_row2_col3" class="data row2 col3" >-19.374191</td>
#       <td id="T_f145e_row2_col4" class="data row2 col4" >-0.718675</td>
#     </tr>
#     <tr>
#       <th id="T_f145e_level0_row3" class="row_heading level0 row3" >s4</th>
#       <td id="T_f145e_row3_col0" class="data row3 col0" >4.412488</td>
#       <td id="T_f145e_row3_col1" class="data row3 col1" >18.255620</td>
#       <td id="T_f145e_row3_col2" class="data row3 col2" >19.046238</td>
#       <td id="T_f145e_row3_col3" class="data row3 col3" >2.021466</td>
#       <td id="T_f145e_row3_col4" class="data row3 col4" >14.800388</td>
#     </tr>
#     <tr>
#       <th id="T_f145e_level0_row4" class="row_heading level0 row4" >s5</th>
#       <td id="T_f145e_row4_col0" class="data row4 col0" >31.947353</td>
#       <td id="T_f145e_row4_col1" class="data row4 col1" >27.241657</td>
#       <td id="T_f145e_row4_col2" class="data row4 col2" >-2.990006</td>
#       <td id="T_f145e_row4_col3" class="data row4 col3" >4.809322</td>
#       <td id="T_f145e_row4_col4" class="data row4 col4" >14.574786</td>
#     </tr>
#     <tr>
#       <th id="T_f145e_level0_row5" class="row_heading level0 row5" >bmi^2</th>
#       <td id="T_f145e_row5_col0" class="data row5 col0"

# %% [markdown]
# Compare this to the coefficients for LASSO. Note that:
#
# - Coefficients are smaller than the unregularized case
# - However, many of them remain non-zero
# - MSE has improved, though not as much as lasso

# %% [markdown]
# ## Elastic Net
#
# Finally, we use Elastic Net. Instead of $\lambda_1$ and $\lambda_2$, sklearn's Elastic Net has ```alpha``` and ```l1_ratio```.
#
# Let's use ```l1_ratio = 0.5``` which places equal importance on the l1 and l2 penalties.

# %%
from sklearn.linear_model import ElasticNet

elastic =  make_pipeline(StandardScaler(), ElasticNet(alpha = 1, l1_ratio = 0.5))

# %%
# Cross validate
results = cross_validate(elastic, X, y, scoring = 'neg_mean_squared_error', cv = cv, return_estimator = True)

mse = - results['test_score']
mse.mean()
# Out:
# 3054.585194900448

# %%
# Display coefficients in a nice DataFrame
coefs = pd.DataFrame(index = X.columns)

for i in range(5):
    model = results['estimator'][i]
    coefs[i] = model.named_steps['elasticnet'].coef_ # remember to specify the correct step!

coefs[(coefs != 0).sum(axis = 1) > 0].style.background_gradient(cmap = 'bwr_r', vmin = -100, vmax = 100)
# Out:
# <style type="text/css">
# #T_8e402_row0_col0, #T_8e402_row0_col3, #T_8e402_row0_col4, #T_8e402_row4_col3, #T_8e402_row12_col2, #T_8e402_row12_col3, #T_8e402_row12_col4, #T_8e402_row17_col3, #T_8e402_row17_col4 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_8e402_row0_col1, #T_8e402_row0_col2, #T_8e402_row4_col1, #T_8e402_row4_col4, #T_8e402_row5_col0, #T_8e402_row5_col3, #T_8e402_row5_col4, #T_8e402_row6_col0, #T_8e402_row6_col1, #T_8e402_row6_col2, #T_8e402_row6_col4, #T_8e402_row17_col0, #T_8e402_row17_col1, #T_8e402_row17_col2 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_8e402_row1_col0, #T_8e402_row1_col2, #T_8e402_row16_col0, #T_8e402_row16_col4 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_8e402_row1_col1, #T_8e402_row1_col4, #T_8e402_row7_col1, #T_8e402_row7_col2, #T_8e402_row7_col3, #T_8e402_row7_col4, #T_8e402_row9_col0, #T_8e402_row9_col1, #T_8e402_row9_col2 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_8e402_row1_col3, #T_8e402_row7_col0, #T_8e402_row9_col4 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_8e402_row2_col0, #T_8e402_row2_col2, #T_8e402_row2_col3, #T_8e402_row2_col4, #T_8e402_row13_col2, #T_8e402_row13_col3, #T_8e402_row13_col4, #T_8e402_row14_col1, #T_8e402_row14_col2, #T_8e402_row14_col3 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_8e402_row2_col1, #T_8e402_row13_col1, #T_8e402_row14_col0, #T_8e402_row14_col4 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_8e402_row3_col0, #T_8e402_row3_col1, #T_8e402_row3_col2, #T_8e402_row3_col3, #T_8e402_row3_col4, #T_8e402_row11_col1, #T_8e402_row11_col2, #T_8e402_row15_col1, #T_8e402_row15_col2, #T_8e402_row15_col3, #T_8e402_row15_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_8e402_row4_col0, #T_8e402_row4_col2, #T_8e402_row5_col1, #T_8e402_row5_col2, #T_8e402_row6_col3, #T_8e402_row8_col3 {
#   background-color: #ececff;
#   color: #000000;
# }
# #T_8e402_row8_col0, #T_8e402_row8_col1, #T_8e402_row8_col2, #T_8e402_row8_col4 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_8e402_row9_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_8e402_row10_col0, #T_8e402_row10_col1, #T_8e402_row10_col2, #T_8e402_row10_col3, #T_8e402_row10_col4 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_8e402_row11_col0, #T_8e402_row11_col3, #T_8e402_row11_col4, #T_8e402_row15_col0, #T_8e402_row16_col1, #T_8e402_row16_col2, #T_8e402_row16_col3 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_8e402_row12_col0, #T_8e402_row12_col1 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_8e402_row13_col0 {
#   background-color: #fffafa;
#   color: #000000;
# }
# </style>
# <table id="T_8e402">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e402_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8e402_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8e402_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_8e402_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_8e402_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e402_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_8e402_row0_col0" class="data row0 col0" >5.645599</td>
#       <td id="T_8e402_row0_col1" class="data row0 col1" >6.805795</td>
#       <td id="T_8e402_row0_col2" class="data row0 col2" >6.366060</td>
#       <td id="T_8e402_row0_col3" class="data row0 col3" >5.774095</td>
#       <td id="T_8e402_row0_col4" class="data row0 col4" >5.816832</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row1" class="row_heading level0 row1" >bp</th>
#       <td id="T_8e402_row1_col0" class="data row1 col0" >2.076964</td>
#       <td id="T_8e402_row1_col1" class="data row1 col1" >2.391189</td>
#       <td id="T_8e402_row1_col2" class="data row1 col2" >2.069807</td>
#       <td id="T_8e402_row1_col3" class="data row1 col3" >3.339551</td>
#       <td id="T_8e402_row1_col4" class="data row1 col4" >2.622117</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row2" class="row_heading level0 row2" >s3</th>
#       <td id="T_8e402_row2_col0" class="data row2 col0" >-2.552644</td>
#       <td id="T_8e402_row2_col1" class="data row2 col1" >-3.183017</td>
#       <td id="T_8e402_row2_col2" class="data row2 col2" >-2.843448</td>
#       <td id="T_8e402_row2_col3" class="data row2 col3" >-2.898249</td>
#       <td id="T_8e402_row2_col4" class="data row2 col4" >-2.970336</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row3" class="row_heading level0 row3" >s4</th>
#       <td id="T_8e402_row3_col0" class="data row3 col0" >0.120324</td>
#       <td id="T_8e402_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_8e402_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8e402_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_8e402_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row4" class="row_heading level0 row4" >s5</th>
#       <td id="T_8e402_row4_col0" class="data row4 col0" >7.079245</td>
#       <td id="T_8e402_row4_col1" class="data row4 col1" >6.807562</td>
#       <td id="T_8e402_row4_col2" class="data row4 col2" >7.146600</td>
#       <td id="T_8e402_row4_col3" class="data row4 col3" >6.041671</td>
#       <td id="T_8e402_row4_col4" class="data row4 col4" >6.674847</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row5" class="row_heading level0 row5" >bmi^2</th>
#       <td id="T_8e402_row5_col0" class="data row5 col0" >6.947498</td>
#       <td id="T_8e402_row5_col1" class="data row5 col1" >7.694962</td>
#       <td id="T_8e402_row5_col2" class="data row5 col2" >7.457524</td>
#       <td id="T_8e402_row5_col3" class="data row5 col3" >6.261882</td>
#       <td id="T_8e402_row5_col4" class="data row5 col4" >6.579938</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row6" class="row_heading level0 row6" >bmi bp</th>
#       <td id="T_8e402_row6_col0" class="data row6 col0" >6.620542</td>
#       <td id="T_8e402_row6_col1" class="data row6 col1" >6.435507</td>
#       <td id="T_8e402_row6_col2" class="data row6 col2" >6.913389</td>
#       <td id="T_8e402_row6_col3" class="data row6 col3" >7.100866</td>
#       <td id="T_8e402_row6_col4" class="data row6 col4" >6.596009</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row7" class="row_heading level0 row7" >bmi s4</th>
#       <td id="T_8e402_row7_col0" class="data row7 col0" >3.475683</td>
#       <td id="T_8e402_row7_col1" class="data row7 col1" >2.770564</td>
#       <td id="T_8e402_row7_col2" class="data row7 col2" >2.669477</td>
#       <td id="T_8e402_row7_col3" class="data row7 col3" >2.903973</td>
#       <td id="T_8e402_row7_col4" class="data row7 col4" >2.999932</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row8" class="row_heading level0 row8" >bmi s5</th>
#       <td id="T_8e402_row8_col0" class="data row8 col0" >7.886115</td>
#       <td id="T_8e402_row8_col1" class="data row8 col1" >8.496797</td>
#       <td id="T_8e402_row8_col2" class="data row8 col2" >8.313484</td>
#       <td id="T_8e402_row8_col3" class="data row8 col3" >7.098137</td>
#       <td id="T_8e402_row8_col4" class="data row8 col4" >7.827845</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row9" class="row_heading level0 row9" >bp^2</th>
#       <td id="T_8e402_row9_col0" class="data row9 col0" >2.908898</td>
#       <td id="T_8e402_row9_col1" class="data row9 col1" >2.701184</td>
#       <td id="T_8e402_row9_col2" class="data row9 col2" >2.721377</td>
#       <td id="T_8e402_row9_col3" class="data row9 col3" >4.094017</td>
#       <td id="T_8e402_row9_col4" class="data row9 col4" >3.319238</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row10" class="row_heading level0 row10" >bp s3</th>
#       <td id="T_8e402_row10_col0" class="data row10 col0" >-0.579266</td>
#       <td id="T_8e402_row10_col1" class="data row10 col1" >-0.663898</td>
#       <td id="T_8e402_row10_col2" class="data row10 col2" >-0.612138</td>
#       <td id="T_8e402_row10_col3" class="data row10

# %% [markdown]
# # Summary
#
# In summary, we've seen that feature selection, Lasso, Ridge and Elastic Net all have improved our model, but in different ways (they all ended up with different feature coefficients).
#
# In this particular case, feature selection and Lasso worked quite well. But results might differ on other datasets.
#
# Note that we haven't even tried varying the regularization parameters! We'll see how to do this next time!
